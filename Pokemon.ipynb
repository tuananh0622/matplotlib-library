# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\MyPC\OneDrive\Máy tính\pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.loc[df['Type 2'].isna()]
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander    Fire    NaN   39      52       43       60       50
# 5      5  Charmeleon    Fire    NaN   58      64       58       80       65
# 9      7    Squirtle   Water    NaN   44      48       65       50       64
# 10     8   Wartortle   Water    NaN   59      63       80       65       80
# 11     9   Blastoise   Water    NaN   79      83      100       85      105
# ..   ...         ...     ...    ...  ...     ...      ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706      Goodra  Dragon    NaN   90     100       70      110      150
# 788  712    Bergmite     Ice    NaN   55      69       85       32       35
# 789  713     Avalugg     Ice    NaN   95     117      184       44       46
# 792  716     Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.fillna('None',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      800 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df[['Name','Type 1','Type 2']]
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire    None
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
df.iloc[15:20]
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 15  12             Butterfree    Bug  Flying  60      45       50       90
# 16  13                 Weedle    Bug  Poison  40      35       30       20
# 17  14                 Kakuna    Bug  Poison  45      25       50       25
# 18  15               Beedrill    Bug  Poison  65      90       40       45
# 19  15  BeedrillMega Beedrill    Bug  Poison  65     150       40       15
#
#     Sp. Def  Speed  Generation  Legendary
# 15       80     70           1      False
# 16       20     50           1      False
# 17       25     35           1      False
# 18       80     75           1      False
# 19       80    145           1      False

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire    None  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
cols = list(df.columns.values)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# new dataframe
df = df[cols[:4]+cols[-1:]+cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# filtering data
df.loc[(df['Type 1'] == 'Bug') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 16    13                 Weedle    Bug  Poison    195  40      35       30
# 17    14                 Kakuna    Bug  Poison    205  45      25       50
# 18    15               Beedrill    Bug  Poison    395  65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495  65     150       40
# 53    48                Venonat    Bug  Poison    305  60      55       50
# 54    49               Venomoth    Bug  Poison    450  70      65       60
# 181  167               Spinarak    Bug  Poison    250  40      60       40
# 182  168                Ariados    Bug  Poison    390  70      90       70
# 292  269                 Dustox    Bug  Poison    385  60      50       70
# 603  543               Venipede    Bug  Poison    260  30      45       59
# 604  544             Whirlipede    Bug  Poison    360  40      55       99
# ...

# %%
df.loc[df['Type 1'].isin(['Bug','Fire'])]
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire    None    309  39      52
# 5      5                 Charmeleon   Fire    None    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 733  665                     Spewpa    Bug    None    213  45      22
# 734  666                   Vivillon    Bug  Flying    411  80      52
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# ...

# %%
df.nunique()
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         19
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df[df['Type 1'] == 'Bug']
# Out:
#        #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 13    10    Caterpie    Bug    None    195  45      30       35       20
# 14    11     Metapod    Bug    None    205  50      20       55       25
# 15    12  Butterfree    Bug  Flying    395  60      45       50       90
# 16    13      Weedle    Bug  Poison    195  40      35       30       20
# 17    14      Kakuna    Bug  Poison    205  45      25       50       25
# ..   ...         ...    ...     ...    ...  ..     ...      ...      ...
# 698  637   Volcarona    Bug    Fire    550  85      60       65      135
# 717  649    Genesect    Bug   Steel    600  71     120       95      120
# 732  664  Scatterbug    Bug    None    200  38      35       40       27
# 733  665      Spewpa    Bug    None    213  45      22       60       27
# 734  666    Vivillon    Bug  Flying    411  80      52       50       90
#
#      Sp. Def  Speed  Generation  Legendary
# 13        20     45           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Bug']
# Out:
#        #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 13    10    Caterpie    Bug    None    195  45      30       35       20
# 14    11     Metapod    Bug    None    205  50      20       55       25
# 15    12  Butterfree    Bug  Flying    395  60      45       50       90
# 16    13      Weedle    Bug  Poison    195  40      35       30       20
# 17    14      Kakuna    Bug  Poison    205  45      25       50       25
# ..   ...         ...    ...     ...    ...  ..     ...      ...      ...
# 698  637   Volcarona    Bug    Fire    550  85      60       65      135
# 717  649    Genesect    Bug   Steel    600  71     120       95      120
# 732  664  Scatterbug    Bug    None    200  38      35       40       27
# 733  665      Spewpa    Bug    None    213  45      22       60       27
# 734  666    Vivillon    Bug  Flying    411  80      52       50       90
#
#      Sp. Def  Speed  Generation  Legendary
# 13        20     45           1      False
# ...

# %%
df.groupby('Attack').max()
# Out:
#           #                     Name   Type 1    Type 2  Total   HP  Defense  \
# Attack
# 5       440                  Happiny   Normal      None    450  250        5
# 10      242                  Shuckle    Water      Rock    540  255      230
# 15      349                   Feebas    Water      None    200   20       20
# 20      458                   Togepi    Water      None    345   70       65
# 22      665                   Spewpa      Bug      None    213   45       60
# ...     ...                      ...      ...       ...    ...  ...      ...
# 165     475                Rampardos     Rock      None    618   97       95
# 170     646       KyuremBlack Kyurem   Dragon       Ice    700  125      115
# 180     386    RayquazaMega Rayquaza  Psychic      None    780  105      160
# 185     214  HeracrossMega Heracross      Bug  Fighting    600   80      115
# 190     150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106      100
#
# ...

# %%
df.groupby('Attack').min()
# Out:
#           #                     Name   Type 1    Type 2  Total   HP  Defense  \
# Attack
# 5       113                  Chansey   Normal      None    220  100        5
# 10      129                  Blissey      Bug      None    200   20       10
# 15      349                   Feebas    Water      None    200   20       20
# 20       11                     Abra      Bug     Fairy    190   25       15
# 22      665                   Spewpa      Bug      None    213   45       60
# ...     ...                      ...      ...       ...    ...  ...      ...
# 165     354      BanetteMega Banette    Ghost  Fighting    495   64       60
# 170     445    GarchompMega Garchomp   Dragon    Ground    700  108      100
# 180     383       DeoxysAttack Forme   Dragon      Fire    600   50       20
# 185     214  HeracrossMega Heracross      Bug  Fighting    600   80      115
# 190     150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106      100
#
# ...

# %%
df.sort_values(['Attack'])
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 488  440                  Happiny   Normal      None    220  100       5
# 121  113                  Chansey   Normal      None    450  250       5
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 261  242                  Blissey   Normal      None    540  255      10
# 139  129                 Magikarp    Water      None    200   20      10
# ..   ...                      ...      ...       ...    ...  ...     ...
# 429  386       DeoxysAttack Forme  Psychic      None    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.groupby('Attack').get_group(190)
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
# rename column label (columns={'old name' : 'new name'})
# or ({'old name' : 'new name'},axis=1)
df.rename(columns={'Sp. Atk':'Atk Speed','Sp. Def':'Def Speed'},errors='raise')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# finding mean values for numerical columns
total_mean = df.mean(numeric_only=True)

# %%
import matplotlib.pyplot as plt
# labels = list(df.columns.values)

# %%
df['Name'].str[0:4]
# Out:
# 0      Bulb
# 1      Ivys
# 2      Venu
# 3      Venu
# 4      Char
#        ...
# 795    Dian
# 796    Dian
# 797    Hoop
# 798    Hoop
# 799    Volc
# Name: Name, Length: 800, dtype: object

# %%
df['Name'].str.split( ).str.get(-1)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3        Venusaur
# 4      Charmander
#           ...
# 795       Diancie
# 796       Diancie
# 797      Confined
# 798       Unbound
# 799     Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# remove all records (rows) where Attack is below 5
df[~(df['Attack'] <= 5)]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df['HP'] = df['HP'].apply(lambda x: x+5)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  50      49       49
# 1      2                Ivysaur    Grass  Poison    405  65      62       63
# 2      3               Venusaur    Grass  Poison    525  85      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  85     100      123
# 4      4             Charmander     Fire    None    309  44      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  55     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  55     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  85     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  85     160       60
# 799  721              Volcanion     Fire   Water    600  85     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  50      49       49
# 1  2                Ivysaur  Grass  Poison    405  65      62       63
# 2  3               Venusaur  Grass  Poison    525  85      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  85     100      123
# 4  4             Charmander   Fire    None    309  44      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.Speed.value_counts()
# Out:
# 50     46
# 60     44
# 70     37
# 65     36
# 30     35
#        ..
# 39      1
# 24      1
# 82      1
# 113     1
# 123     1
# Name: Speed, Length: 108, dtype: int64

# %%
# change row entries by using .map
df['New Life'] = df['Generation'].map({1: 'Number one', 2 : 'Number two'})
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  50      49       49
# 1      2                Ivysaur    Grass  Poison    405  65      62       63
# 2      3               Venusaur    Grass  Poison    525  85      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  85     100      123
# 4      4             Charmander     Fire    None    309  44      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  55     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  55     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  85     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  85     160       60
# 799  721              Volcanion     Fire   Water    600  85     110      120
#
# ...

# %%
df.groupby('Type 1').Total.describe()
# Out:
#           count        mean         std    min     25%    50%     75%    max
# Type 1
# Bug        69.0  378.927536  117.875223  194.0  269.00  395.0  475.00  600.0
# Dark       31.0  445.741935  109.126217  220.0  359.00  465.0  510.00  680.0
# Dragon     32.0  550.531250  146.267538  300.0  420.00  600.0  680.00  780.0
# Electric   44.0  443.409091  105.721952  205.0  362.25  477.5  520.00  610.0
# Fairy      17.0  413.176471  123.781680  218.0  323.00  405.0  483.00  680.0
# Fighting   27.0  416.444444  102.464378  210.0  326.50  455.0  497.50  625.0
# Fire       52.0  458.076923  109.760496  250.0  368.00  482.0  534.00  680.0
# Flying      4.0  485.000000  161.400124  245.0  462.50  557.5  580.00  580.0
# Ghost      32.0  439.562500  110.072685  275.0  335.00  464.5  495.75  680.0
# Grass      70.0  421.142857  106.650626  180.0  318.50  430.0  497.00  630.0
# Ground     32.0  437.500000  123.913081  265.0  329.50  440.0  512.25  770.0
# ...

# %%
df.loc[df['Total'] == 770.0]
# Out:
#        #                   Name  Type 1 Type 2  Total   HP  Attack  Defense  \
# 422  382    KyogrePrimal Kyogre   Water   None    770  105     150       90
# 424  383  GroudonPrimal Groudon  Ground   Fire    770  105     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary New Life
# 422      180      160     90           3       True      NaN
# 424      150       90     90           3       True      NaN

# %%
df.groupby(df['Name'].str.contains('Venusaur')).Total.describe()
# Out:
#        count       mean         std    min    25%    50%    75%    max
# Name
# False  798.0  434.75188  119.882172  180.0  330.0  450.0  515.0  780.0
# True     2.0  575.00000   70.710678  525.0  550.0  575.0  600.0  625.0

# %%
import re
df['Name'][df['Name'].str.contains('^Be',flags=re.I)]
# Out:
# 18                  Beedrill
# 19     BeedrillMega Beedrill
# 75                Bellsprout
# 197                Bellossom
# 290                Beautifly
# 410                   Beldum
# 667                 Beheeyem
# 675                  Beartic
# 788                 Bergmite
# Name: Name, dtype: object
