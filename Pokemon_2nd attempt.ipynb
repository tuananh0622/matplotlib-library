# %%
import pandas as pd
import numpy as np

# %%
# read csv file
df = pd.read_csv('pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# we need more information about this data
# as we can see, there are 800 entries, 12 columns, in which there are 8 int64, 3 object and 1 boolean type.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# we want to display all of the column labels
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
# we can transpose the DF to swap columns and rows
df.T
# Out:
#                   0        1         2                      3           4    \
# #                   1        2         3                      3           4
# Name        Bulbasaur  Ivysaur  Venusaur  VenusaurMega Venusaur  Charmander
# Type 1          Grass    Grass     Grass                  Grass        Fire
# Type 2         Poison   Poison    Poison                 Poison         NaN
# HP                 45       60        80                     80          39
# Attack             49       62        82                    100          52
# Defense            49       63        83                    123          43
# Sp. Atk            65       80       100                    122          60
# Sp. Def            65       80       100                    120          50
# Speed              45       60        80                     80          65
# Generation          1        1         1                      1           1
# ...

# %%
# make a df of three columns
df[['Type 1','Type 2','Name']]
# Out:
#       Type 1  Type 2                   Name
# 0      Grass  Poison              Bulbasaur
# 1      Grass  Poison                Ivysaur
# 2      Grass  Poison               Venusaur
# 3      Grass  Poison  VenusaurMega Venusaur
# 4       Fire     NaN             Charmander
# ..       ...     ...                    ...
# 795     Rock   Fairy                Diancie
# 796     Rock   Fairy    DiancieMega Diancie
# 797  Psychic   Ghost    HoopaHoopa Confined
# 798  Psychic    Dark     HoopaHoopa Unbound
# 799     Fire   Water              Volcanion
#
# [800 rows x 3 columns]

# %%
# illustrate only one row which you prefer
df.loc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
# display how many null within your data
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# display a few rows depending on your choice
df.loc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# display thing following by index
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# pointing exactly the position at row 3 and column 5
df.iloc[3,5]
# Out:
# 100

# %%
# what will happen if I want to list all rows exclusively including 'Grass' in column Type 1
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# how about more than 50 attack speed and 50 defend speed
df.loc[(df['Sp. Atk'] > 50) & (df['Sp. Def'] > 50)]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 5      5             Charmeleon     Fire     NaN  58      64       58
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.describe()
# the lowest Hp is 1 opposite to 225 of maximum hp
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# next I going to sort values
df.sort_values('Name',ascending=True)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# sorting values by Type 1 and highest attack
df.sort_values(['Type 1','Attack'],ascending=False)
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 141  130  GyaradosMega Gyarados  Water    Dark   95     155      109       70
# 283  260  SwampertMega Swampert  Water  Ground  100     150      110       95
# 422  382    KyogrePrimal Kyogre  Water     NaN  100     150       90      180
# 349  319  SharpedoMega Sharpedo  Water    Dark   70     140       70      110
# 107   99                Kingler  Water     NaN   55     130      115       50
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 446  401              Kricketot    Bug     NaN   37      25       41       25
# 733  665                 Spewpa    Bug     NaN   45      22       60       27
# 14    11                Metapod    Bug     NaN   50      20       55       25
# 179  165                 Ledyba    Bug  Flying   40      20       30       40
# 230  213                Shuckle    Bug    Rock   20      10      230       10
#
# ...

# %%
# how about making the first column sort ascending and the second do a reverse
df.sort_values(['Type 1','Attack'],ascending=(1,0))
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 137  127        PinsirMega Pinsir    Bug    Flying  65     155      120
# 19    15    BeedrillMega Beedrill    Bug    Poison  65     150       40
# 229  212        ScizorMega Scizor    Bug     Steel  70     150      140
# 650  589               Escavalier    Bug     Steel  70     135      105
# ..   ...                      ...    ...       ...  ..     ...      ...
# 405  370                  Luvdisc  Water       NaN  43      30       55
# 198  183                   Marill  Water     Fairy  70      20       50
# 508  458                  Mantyke  Water    Flying  45      20       50
# 381  349                   Feebas  Water       NaN  20      15       20
# 139  129                 Magikarp  Water       NaN  20      10       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# create a new column
# df['Total'] = df.eval('HP + Attack + Defense + (Sp. Atk) + (Sp. Def) + Speed') # make a problem with Sp. Atk and Def
# df

# %%
# axis=0 refers to horizontal axis or rows
# axis=1 refers to vertical axis or columns
df['Total'] = df.iloc[:,4:10].sum(axis=1) # summation of all values in each columns
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.reset_index(drop=True)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.loc[df['Name'] == 'Bulbasaur']
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary  Total
# 0           1      False    318

# %%
df.iloc[0:3,0:3]
# Out:
#    #       Name Type 1
# 0  1  Bulbasaur  Grass
# 1  2    Ivysaur  Grass
# 2  3   Venusaur  Grass

# %%
# this is only an array
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype=object)

# %%
# change the position of a specific column
# at first, make a list for all column labels
cols = list(df.columns.values)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df = df[cols[0:4]+cols[-1:]+cols[4:12]] # only concatenate list, not string since cols[-1] is a string
# but cols[-1:] is a list
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# find a specific name within a column
mega = df.loc[df['Name'].str.contains('Mega')]
mega.head(5)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass')]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 1'] == 'Fire')]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Name'].str.contains('va',flags=re.I)] # flags=re.I is imply ignoring upper case
# Out:
#        #        Name  Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 145  134    Vaporeon   Water       NaN    525  130      65       60      110
# 170  156     Quilava    Fire       NaN    405   58      64       58       80
# 347  318    Carvanha   Water      Dark    305   45      90       20       65
# 360  329     Vibrava  Ground    Dragon    340   50      70       50       50
# 602  542    Leavanny     Bug     Grass    500   75     103       80       70
# 643  582   Vanillite     Ice       NaN    305   36      50       50       65
# 644  583   Vanillish     Ice       NaN    395   51      65       65       80
# 645  584   Vanilluxe     Ice       NaN    535   71      95       85      110
# 650  589  Escavalier     Bug     Steel    495   70     135      105       60
# 657  596  Galvantula     Bug  Electric    472   70      77       60       97
# 789  713     Avalugg     Ice       NaN    514   95     117      184       44
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('^va',flags=re.I)] # flags=re.I is imply ignoring upper case
# Out:
#        #       Name Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 145  134   Vaporeon  Water    NaN    525  130      65       60      110
# 643  582  Vanillite    Ice    NaN    305   36      50       50       65
# 644  583  Vanillish    Ice    NaN    395   51      65       65       80
# 645  584  Vanilluxe    Ice    NaN    535   71      95       85      110
#
#      Sp. Def  Speed  Generation  Legendary
# 145       95     65           1      False
# 643       60     44           5      False
# 644       75     59           5      False
# 645       95     79           5      False

# %%
df.loc[df['Type 1'] == 'Fire','Type 2'] = 'Flamer'
df.to_csv('Adding Flamer.csv')

# %%
new_df.isna().sum()
# Out:
# Unnamed: 0      0
# #               0
# Name            0
# Type 1          0
# Type 2        299
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
new_df = pd.read_csv('Adding Flamer.csv')
new_df.head()
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  HP  Attack  \
# 0           0  1              Bulbasaur  Grass  Poison    318  45      49
# 1           1  2                Ivysaur  Grass  Poison    405  60      62
# 2           2  3               Venusaur  Grass  Poison    525  80      82
# 3           3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100
# 4           4  4             Charmander   Fire  Flamer    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# 2       83      100      100     80           1      False
# 3      123      122      120     80           1      False
# 4       43       60       50     65           1      False

# %%
# finding which rows are null
new_df[new_df.isna().any(axis=1)]
# Out:
#      Unnamed: 0    #                     Name  Type 1 Type 2  Total   HP  \
# 9             9    7                 Squirtle   Water    NaN    314   44
# 10           10    8                Wartortle   Water    NaN    405   59
# 11           11    9                Blastoise   Water    NaN    530   79
# 12           12    9  BlastoiseMega Blastoise   Water    NaN    630   79
# 13           13   10                 Caterpie     Bug    NaN    195   45
# ..          ...  ...                      ...     ...    ...    ...  ...
# 775         775  705                  Sliggoo  Dragon    NaN    452   68
# 776         776  706                   Goodra  Dragon    NaN    600   90
# 788         788  712                 Bergmite     Ice    NaN    304   55
# 789         789  713                  Avalugg     Ice    NaN    514   95
# 792         792  716                  Xerneas   Fairy    NaN    680  126
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
new_df.loc[new_df['Type 1'] == 'Water']
# Out:
#      Unnamed: 0    #                     Name Type 1 Type 2  Total  HP  \
# 9             9    7                 Squirtle  Water    NaN    314  44
# 10           10    8                Wartortle  Water    NaN    405  59
# 11           11    9                Blastoise  Water    NaN    530  79
# 12           12    9  BlastoiseMega Blastoise  Water    NaN    630  79
# 59           59   54                  Psyduck  Water    NaN    320  50
# ..          ...  ...                      ...    ...    ...    ...  ..
# 724         724  656                  Froakie  Water    NaN    314  41
# 725         725  657                Frogadier  Water    NaN    405  54
# 726         726  658                 Greninja  Water   Dark    530  72
# 762         762  692                Clauncher  Water    NaN    330  50
# 763         763  693                Clawitzer  Water    NaN    500  71
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
new_df.loc[new_df['Type 1'] == 'Water', 'Type 2'] = 'Dark'

# %%
new_df.loc[new_df['Type 1'] == 'Ice']
# Out:
#      Unnamed: 0    #               Name Type 1   Type 2  Total   HP  Attack  \
# 133         133  124               Jynx    Ice  Psychic    455   65      50
# 156         156  144           Articuno    Ice   Flying    580   90      85
# 238         238  220             Swinub    Ice   Ground    250   50      50
# 239         239  221          Piloswine    Ice   Ground    450  100     100
# 243         243  225           Delibird    Ice   Flying    330   45      55
# 257         257  238           Smoochum    Ice  Psychic    305   45      30
# 395         395  361            Snorunt    Ice      NaN    300   50      50
# 396         396  362             Glalie    Ice      NaN    480   80      80
# 397         397  362  GlalieMega Glalie    Ice      NaN    580   80     120
# 398         398  363             Spheal    Ice    Water    290   70      40
# 399         399  364             Sealeo    Ice    Water    410   90      60
# ...
